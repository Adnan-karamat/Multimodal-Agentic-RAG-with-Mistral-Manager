# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
## Libraries Required
# !pip install langchain-huggingface
## For API Calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install  bitsandbytes
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.7/408.7 kB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.8/255.8 kB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: requests-toolbelt
#     Found existing installation: requests-toolbelt 0.10.1
#     Uninstalling requests-toolbelt-0.10.1:
#       Successfully uninstalled requests-toolbelt-0.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
# Directly set your Hugging Face API token (replace 'your_token_here' with your actual token)
sec_key = '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'
print(sec_key)  # Again, be cautious with printing sensitive information
# Out:
# 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

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.2"
llm=HuggingFaceEndpoint(repo_id=repo_id,max_length=128,temperature=0.7,token=sec_key)

# %%
llm.invoke("What is machine learning")
# Out:
# '? Machine learning is a subset of artificial intelligence, which involves feeding large datasets into algorithms to help them learn and improve their ability to perform tasks without explicit programming. It’s a form of pattern recognition and statistical analysis that enables computers to learn and make decisions based on data.\n\nMachine learning algorithms can be broken down into three main categories: supervised learning, unsupervised learning, and reinforcement learning. Supervised learning involves training the algorithm on labeled data, where the desired output is already known. Unsupervised learning, on the other hand, involves training the algorithm on unlabeled data, where the desired output is not known. Reinforcement learning involves training the algorithm to learn by interacting with its environment and receiving feedback in the form of rewards or punishments.\n\nMachine learning has numerous applications in various industries, including healthcare, finance, marketing,
# ...

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("HF_TOKEN")

# %%
import os
from huggingface_hub import login

hf_token = os.getenv('HF_TOKEN')
login(hf_token)

# %%
from huggingface_hub.utils import HfHubHTTPError

for _ in range(5):  # Number of attempts
    try:
        response = llm.invoke("What is deep learning?")
        print(response)
        break  # Exit loop if successful
    except HfHubHTTPError as e:
        if e.response.status_code == 429:  # Too Many Requests
            print("Rate limit hit, sleeping...")
            time.sleep(10)  # Wait before retrying
        else:
            raise  # Raise other errors
# Out:
# Rate limit hit, sleeping...
# Rate limit hit, sleeping...
# Rate limit hit, sleeping...
# Rate limit hit, sleeping...
# Rate limit hit, sleeping...

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.3"
llm=HuggingFaceEndpoint(repo_id=repo_id,max_length=128,temperature=0.7,token=sec_key)

# %%
llm.invoke("What is Genertaive AI")
# Out:
# '?\n\nGenerative AI refers to a type of artificial intelligence (AI) that can create new content, such as text, images, or music, based on the data it has been trained on. It works by learning patterns and structures in the data and then using these patterns to generate new content that is similar in style and form to the original data.\n\nThere are several types of generative AI, including:\n\n1. Deep Learning Generative Models: These are neural networks that are trained to generate new data by learning the underlying distribution of the data they were trained on. Examples of deep learning generative models include Generative Adversarial Networks (GANs), Variational Autoencoders (VAEs), and Autoencoders.\n2. Markov Chains: These are statistical models that can generate sequences of data based on the probability of each element in the sequence being followed by another element. They are commonly used in natural language processing to generate text.\n3. Recurrent Neural Networks (RNNs
# ...

# %%
llm.invoke("What is computer vision")
# Out:
# '?\n\nComputer vision is a field of computer science that focuses on the development of algorithms and statistical models that allow computers to interpret and understand the visual world. The goal of computer vision is to enable computers to process and analyze images and videos in a way that is similar to how humans do.\n\nComputer vision tasks can include object recognition, facial recognition, image segmentation, and 3D reconstruction, among others. These tasks involve processing images and videos, extracting relevant features, and making decisions based on the extracted information. Computer vision is used in a wide range of applications, including autonomous vehicles, robotics, security, healthcare, and entertainment.\n\nThe development of computer vision has been driven by advances in machine learning, particularly deep learning, which has allowed for the creation of powerful models that can learn to recognize and understand complex visual patterns. However, computer vision re
# ...

# %%
from langchain import PromptTemplate, LLMChain

question="Who was the founder of the neural network?"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="Question: {question}\nAnswer: Let's think step by step."

# %%
llm_chain=LLMChain(llm=llm,prompt=prompt)
print(llm_chain.invoke(question))
# Out:
# /tmp/ipykernel_30/3919080688.py:1: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   llm_chain=LLMChain(llm=llm,prompt=prompt)
# ...

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
